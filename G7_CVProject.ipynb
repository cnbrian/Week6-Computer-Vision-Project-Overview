# %% [markdown]
# <a href="https://colab.research.google.com/github/cnbrian/Week6-Computer-Vision-Project-Overview/blob/main/G7_CVProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### 2. Prepare data ###

# !scp '/content/drive/My Drive/IAT481CVProject/ASL_Dataset.zip' '/content/ASL_Dataset.zip'

# !unzip '/content/ASL_Dataset.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/ASL_Dataset/train/W/W2815.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W2815.jpg
#   inflating: /content/ASL_Dataset/train/W/W545.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W545.jpg
#   inflating: /content/ASL_Dataset/train/W/W2801.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W2801.jpg
#   inflating: /content/ASL_Dataset/train/W/W73.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W73.jpg
#   inflating: /content/ASL_Dataset/train/W/W223.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W223.jpg
#   inflating: /content/ASL_Dataset/train/W/W2197.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W2197.jpg
#   inflating: /content/ASL_Dataset/train/W/W2829.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W2829.jpg
#   inflating: /content/ASL_Dataset/train/W/W579.jpg
#   inflating: /content/__MACOSX/ASL_Dataset/train/W/._W579.jpg
# ...

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.1/720.1 kB 10.1 MB/s eta 0:00:00
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data='/content/ASL_Dataset/', epochs=5)  # train the model
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 19.9MB/s]
# Ultralytics YOLOv8.1.25 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### 5. Copy results ###

# !scp -r /content/runs '/content/drive/My Drive/IAT481CVProject'
